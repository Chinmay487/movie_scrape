# %% [markdown]
# Name : Chinmay Patil

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('movies.csv')

# %%
pd.set_option('display.float_format', lambda x: f'{x:,.3f}')

# %%
df.head()
# Out:
#            budget         revenue  content_score  user_score  \
# 0 150,000,000.000 430,238,384.000        100.000      79.000
# 1 242,000,000.000 708,000,000.000        100.000      76.000
# 2 110,000,000.000 424,000,000.000        100.000      68.000
# 3             NaN             NaN        100.000      82.000
# 4             NaN             NaN        100.000      57.000
#
#                              genres               director  release_year  \
# 0          Action,Adventure,Fantasy  Destin Daniel Cretton     2,021.000
# 1         Adventure,Action,Thriller     Cary Joji Fukunaga     2,021.000
# 2  Science Fiction,Action,Adventure           Kelly Marcel     2,021.000
# 3   Science Fiction,Drama,Adventure       Miguel Sapochnik     2,021.000
# 4   Action,Thriller,Science Fiction           Edward Drake     2,021.000
#
#    release_month  release_day  release_weekday  run_time (in minuts)  \
# 0          9.000        3.000            4.000               132.000
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of               budget         revenue  content_score  user_score  \
# 0    150,000,000.000 430,238,384.000        100.000      79.000
# 1    242,000,000.000 708,000,000.000        100.000      76.000
# 2    110,000,000.000 424,000,000.000        100.000      68.000
# 3                NaN             NaN        100.000      82.000
# 4                NaN             NaN        100.000      57.000
# ...              ...             ...            ...         ...
# 9995             NaN             NaN        100.000      82.000
# 9996  19,000,000.000 272,742,922.000        100.000      83.000
# 9997             NaN             NaN        100.000      58.000
# 9998             NaN             NaN        100.000      64.000
# 9999             NaN  11,879,046.000        100.000      73.000
#
#                                       genres               director  \
# 0                   Action,Adventure,Fantasy  Destin Daniel Cretton
# ...

# %%
df.describe()
# Out:
#                budget           revenue  content_score  user_score  \
# count       5,318.000         5,388.000      9,980.000   9,937.000
# mean   35,770,617.209   107,288,822.500         97.268      63.390
# std    43,637,399.150   188,634,767.229         10.044      13.614
# min             1.000             1.000          7.000       0.000
# 25%     7,500,000.000    10,743,807.000        100.000      59.000
# 50%    20,000,000.000    42,019,542.500        100.000      65.000
# 75%    45,000,000.000   119,224,113.250        100.000      71.000
# max   380,000,000.000 2,847,246,203.000        100.000     100.000
#
#        release_year  release_month  release_day  release_weekday  \
# count     9,980.000      9,980.000    9,980.000        9,980.000
# mean      2,007.830          6.974       15.617            3.345
# std          14.353          3.466        8.676            1.335
# min       1,888.000          1.000        1.000            0.000
# ...

# %%
df['budget'].unique()
# Out:
# array([1.50000000e+08, 2.42000000e+08, 1.10000000e+08,            nan,
#        1.40000000e+07, 1.65000000e+08, 2.00000000e+08, 2.50000000e+05,
#        1.16000000e+08, 3.00000000e+07, 2.00000000e+07, 8.20000000e+07,
#        8.80000000e+07, 1.58000000e+07, 8.40000000e+06, 5.00000000e+06,
#        1.80000000e+08, 2.60000000e+07, 1.61900000e+08, 4.00000000e+07,
#        1.44797400e+07, 1.80000000e+07, 7.00000000e+07, 2.15000000e+08,
#        1.00000000e+07, 3.85044000e+07, 3.90000000e+07, 1.00000000e+08,
#        1.75000000e+08, 1.25000000e+08, 2.17000000e+07, 5.00000000e+07,
#        6.50000000e+07, 2.37000000e+08, 3.00000000e+08, 1.60000000e+08,
#        2.30000000e+07, 6.00000000e+07, 2.90000000e+07, 1.70000000e+07,
#        1.39000000e+08, 6.10000000e+07, 1.30000000e+08, 1.00000000e+06,
#        2.20000000e+08, 2.58000000e+08, 6.50000000e+06, 2.50000000e+08,
#        3.56000000e+08, 1.20000000e+07, 4.50000000e+01, 8.11693500e+06,
# ...
